# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(20)
# random() function is used to generate random numbers in Python. Not actually random, rather this is used to generate pseudo-random numbers. That implies that these randomly generated numbers can be determined. random() function generates numbers for some values. This value is also called seed value. 
x1 = np.random.normal(0, 1, 2500)
x2 = np.random.normal(0, 1, 2500)
x3 = x1 + np.random.normal(0, 1, 2500)
x4 = -x2 + np.random.normal(0, 1, 2500)

df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4})

print(df.describe())

# Creating the scatter matrix:
pd.plotting.scatter_matrix(df)
plt.show()  # Display the scatter matrix plot
# Out:
#                 x1           x2           x3           x4
# count  2500.000000  2500.000000  2500.000000  2500.000000
# mean      0.010025    -0.012331     0.053396     0.035386
# std       0.989364     0.987991     1.410485     1.398660
# min      -3.803853    -3.154196    -5.235260    -4.809690
# 25%      -0.688710    -0.686184    -0.884372    -0.941616
# 50%       0.010833     0.026730     0.063055    -0.023704
# 75%       0.684876     0.636228     1.004553     1.013096
# max       4.035029     3.284869     4.465492     5.495305

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(20)
x1 = np.random.normal(0, 1, 2500)
x2 = np.random.normal(0, 1, 2500)
x3 = x1 + np.random.normal(0, 1, 2500)
x4 = -x2 + np.random.normal(0, 1, 2500)

df = pd.DataFrame({'X1': x1, 'X2': x2, 'X3': x3, 'X4': x4})
corr = df.corr()

# Creating a correlation heatmap
sns.heatmap(corr, cmap="Blues", annot=True)
plt.show()
# While rxy = 0 implies no linear relationship, rxy = 1 and rxy = −1 indicates perfect linear
# relationship with a positive and negative relationship, respectively. Generally, |rxy| > 0.5
# indicates a weak linear dependence, while |rxy| > 0.8 indicates a strong linear dependence

# %%
# Now first we understand about random.seed

# %%
import random
random.seed() # if you not write inside () then number generated all time when you run are different
def print_random():
    for i in range(20):
        print(random.randint(0,100), end=' ')
print_random()
# Out:
# 56 24 73 42 91 98 84 70 8 93 60 81 40 77 41 0 39 84 31 55

# %%
import random
random.seed(20) # if you  write inside ()  any thing other than zero then number generated all time are same
def print_random():
    for i in range(20):
        print(random.randint(0,100), end=' ')
print_random()
# Out:
# 92 87 100 98 19 33 86 81 12 41 73 21 3 52 52 9 13 16 40 60

# %%
import matplotlib.pyplot as plt

xi = [176, 180, 187, 190, 193, 196, 201, 205, 211, 220]
zi = [-1.64, -1.04, -0.67, -0.39, -0.13, 0.13, 0.39, 0.67, 1.04, 1.64]

# Adding subplots
fig = plt.figure(figsize=(20, 7))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.set_xlabel("z_i")
ax1.set_ylabel("x_i")
ax1.plot(zi, xi, "o")
ax1.grid()
res =stats.probplot(xi,plot=ax2)
ax2.grid()
# Display the plots
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

mu, sigma, n = 10, 2, 500
X = np.random.normal(mu, sigma, n)

# Adding subplots
fig = plt.figure(figsize=(20, 7))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

sns.histplot(X, edgecolor='black', ax=ax1)
ax1.set_title("Histogram of X")

res = stats.probplot(X, plot=ax2)
ax2.set_title("Normal Probability Plot")

ax2.grid()
plt.show()
